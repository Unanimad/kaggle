# %%
import requests
import pandas as pd

from bs4 import BeautifulSoup

# %%
base_url = 'https://www.grammy.com'
awards_url = 'https://www.grammy.com/grammys/awards'

# %%
req = requests.get(awards_url)

# %%
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.content, 'html.parser')

# %%
awards = soup.find(class_='views-infinite-scroll-content-wrapper')

# %%
rows = awards.find_all(class_='views-row')

# %%
img = rows[0].a.img['src']

# %%
last_edition_url = f"{base_url}{rows[0].a['href']}"
print(last_edition_url)
# Out:
# https://www.grammy.com/grammys/awards/62nd-annual-grammy-awards-2019

# %%
last_year = last_edition_url.split('-')[4]
print(last_year)
# Out:
# 2019

# %%
req = requests.get(last_edition_url)
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.content, 'html.parser')
all_editions_url = soup.find(class_='view-show-year').find_all(class_='views-row')
len(all_editions_url)
# Out:
# 62

# %%
df = pd.DataFrame(columns=['year', 'title', 'published_at', 'updated_at', \
                           'category', 'nominee', 'artist', 'workers', \
                           'img', 'winner'])

# %%
def insert_row(df, row):
    insert_loc = df.index.max()

    if pd.isna(insert_loc):
        df.loc[0] = row
    else:
        df.loc[insert_loc + 1] = row

# %%
for edition_url in all_editions_url[1:]:
  url = f"{base_url}{edition_url.a['href']}"

  req = requests.get(url)
  if req.status_code == 200:
    soup = BeautifulSoup(req.content, 'html.parser')

    title = soup.find(class_='sub-title').h2.string
    published_at = soup.find("meta",  property="article:published_time")['content']
    updated_at = soup.find("meta",  property="article:modified_time")['content']
    year = soup.find(id='page-title').getText().split(" ")[0]

    articles = soup.find_all(class_='view-grouping')
    for article in articles:
      category = article.find(class_='view-grouping-header').string

      try:
        img = article.find(class_='circular-image').img['src']
      except:
        img = ''

      winner = True
      nominee = article.find(class_='views-field-title').string

      try:
        artist = article.find(class_='views-field-field-description').p.getText()
      except:
        artist = ''

      try:
        workers = article.find(class_='views-field-body-1').p.getText()
      except:
        workers = ''

      insert_row(df, [year, title, published_at, updated_at, category, nominee, \
                  artist, workers, img, winner])

# %%
df.loc[df.artist == '']
# Out:
#       year                              title               published_at  \
# 2     2018  61st Annual GRAMMY Awards  (2018)  2018-12-06T23:48:49-08:00
# 3     2018  61st Annual GRAMMY Awards  (2018)  2018-12-06T23:48:49-08:00
# 13    2018  61st Annual GRAMMY Awards  (2018)  2018-12-06T23:48:49-08:00
# 18    2018  61st Annual GRAMMY Awards  (2018)  2018-12-06T23:48:49-08:00
# 23    2018  61st Annual GRAMMY Awards  (2018)  2018-12-06T23:48:49-08:00
# ...    ...                                ...                        ...
# 4341  1958   1st Annual GRAMMY Awards  (1958)  2017-11-28T00:03:45-08:00
# 4342  1958   1st Annual GRAMMY Awards  (1958)  2017-11-28T00:03:45-08:00
# 4343  1958   1st Annual GRAMMY Awards  (1958)  2017-11-28T00:03:45-08:00
# 4344  1958   1st Annual GRAMMY Awards  (1958)  2017-11-28T00:03:45-08:00
# 4345  1958   1st Annual GRAMMY Awards  (1958)  2017-11-28T00:03:45-08:00
#
#                      updated_at  \
# 2     2019-09-10T01:06:11-07:00
# 3     2019-09-10T01:06:11-07:00
# 13    2019-09-10T01:06:11-07:00
# 18    2019-09-10T01:06:11-07:00
# 23    2019-09-10T01:06:11-07:00
# ...                         ...
# 4341  2019-09-10T01:11:09-07:00
# 4342  2019-09-10T01:11:09-07:00
# 4343  2019-09-10T01:11:09-07:00
# 4344  2019-09-10T01:11:09-07:00
# 4345  2019-09-10T01:11:09-07:00
#
#                                                category  \
# 2                                      Song Of The Year
# 3                                       Best New Artist
# 13                                       Best Rock Song
# 18                                        Best R&B Song
# 23                                        Best Rap Song
# ...                                                 ...
# 4341  Best Classical Performance - Instrumentalist (...
# 4342  Best Classical Performance - Instrumentalist (...
# 4343  Best Classical Performance - Chamber Music (In...
# 4344  Best Classical Performance - Vocal Soloist (Wi...
# 4345    Best Classical Performance - Operatic Or Choral
#
#                                                 nominee artist  \
# 2                                       This Is America
# 3                                              Dua Lipa
# 13                                         Masseduction
# 18                                             Boo'd Up
# 23                                           God's Plan
# ...                                                 ...    ...
# 4341  Tchaikovsky: Piano Concerto No. 1 In B Flat Mi...
# 4342                             Segovia Golden Jubilee
# 4343                             Beethoven: Quartet 130
# 4344                                   Operatic Recital
# 4345                                           Virtuoso
#
#                                                 workers  \
# 2     Donald Glover, Ludwig Göransson & Jeffery Lama...
# 3
# 13    Jack Antonoff & Annie Clark, songwriters (St. ...
# 18    Larrance Dopson, Joelle James, Ella Mai & Dijo...
# 23    Aubrey Graham, Daveon Jackson, Brock Korsan, R...
# ...                                                 ...
# 4341  Van Cliburn, artist (Symphony Of The Air Orche...
# 4342                             Andres Segovia, artist
# 4343  Hollywood String Quartet (Alvin Dinkin, Paul S...
# 4344
# 4345                       Roger Wagner, choir director
#
#                                                     img winner
# 2     https://www.grammy.com/sites/com/files/styles/...   True
# 3                                                         True
# 13    https://www.grammy.com/sites/com/files/styles/...   True
# 18    https://www.grammy.com/sites/com/files/styles/...   True
# 23    https://www.grammy.com/sites/com/files/styles/...   True
# ...                                                 ...    ...
# 4341                                                      True
# 4342  https://www.grammy.com/sites/com/files/styles/...   True
# 4343                                                      True
# 4344                                                      True
# 4345                                                      True
#
# [1647 rows x 10 columns]

# %%
new_df = df.drop(['year', 'published_at', 'updated_at', 'winner'], axis=1)

# %%
human_awards = ['Best New Artist', '']

# %%
new_df.loc[new_df.category == 'Best New Artist']
# Out:
#                                   title         category  \
# 3     61st Annual GRAMMY Awards  (2018)  Best New Artist
# 87    60th Annual GRAMMY Awards  (2017)  Best New Artist
# 171           Chance The Rapper
# 255              Meghan Trainor
# 338                   Sam Smith
# 421     Macklemore & Ryan Lewis
# 503                        Fun.
# 584                    Bon Iver
# 662          Esperanza Spalding
# 770              Zac Brown Band
# 879                       Adele
# 989               Amy Winehouse
# 1099           Carrie Underwood
# 1207                John Legend
# 1315                   Maroon 5
# 1422                Evanescence
# 1527                Norah Jones
# 1631                Alicia Keys
# 1732               Shelby Lynne
# 1832         Christina Aguilera
# 1930                Lauryn Hill
# 2025                 Paula Cole
# 2117                LeAnn Rimes
# 2206      Hootie & The Blowfish
# 2294                Sheryl Crow
# 2381               Toni Braxton
# 2460       Arrested Development
# 2540                  Marc Cohn
# 2618               Mariah Carey
# 2770              Tracy Chapman
# 2846                Jody Watley
# 2917  Bruce Hornsby & The Range
# 2985                       Sade
# 3056               Cyndi Lauper
# 3123               Culture Club
# 3190                Men At Work
# 3252              Sheena Easton
# 3313          Christopher Cross
# 3373           Rickie Lee Jones
# 3431           A Taste Of Honey
# 3678               Bette Midler
# 3952              Bobbie Gentry
# 4043                  Tom Jones
#
#                                                     img
# 3
# 87
# 171
# 255
# 338   https://www.grammy.com/sites/com/files/styles/...
# 421   https://www.grammy.com/sites/com/files/styles/...
# 503   https://www.grammy.com/sites/com/files/styles/...
# 584   https://www.grammy.com/sites/com/files/styles/...
# 662   https://www.grammy.com/sites/com/files/styles/...
# 770   https://www.grammy.com/sites/com/files/styles/...
# 879
# 989
# 1099
# 1207
# 1315
# 1422
# 1527
# 1631
# 1732
# 1832
# 1930
# 2025
# 2117
# 2206
# 2294
# 2381
# 2460
# 2540
# 2618
# 2770
# 2846
# 2917
# 2985
# 3056
# 3123
# 3190
# 3252
# 3313
# 3373
# 3431
# 3678
# 3952
# 4043

# %%
categories_df = pd.DataFrame(data=new_df['category'].unique(), columns=['name'])

# %%
new_df.to_csv(path_or_buf='grammy_awards.csv', index=False, sep=',')

# %%
categories_df.to_csv(path_or_buf='categories.csv', index=False, sep=',')

# %%
new_df.winner = True

# %%
new_df.loc[new_df.winner == True]

# %%
new_df['year'] = new_df.apply(lambda x: x.title[-5:-1], axis=1)
new_df['title'] = new_df.apply(lambda x: x.title[:-7], axis=1)

# %%
new_df.head(3)
# Out:
#    year                       title            category          nominee  \
# 0  2018  61st Annual GRAMMY Awards   Record Of The Year  This Is America
# 1  2018  61st Annual GRAMMY Awards    Album Of The Year      Golden Hour
# 2  2018  61st Annual GRAMMY Awards     Song Of The Year  This Is America
#
#              artist                                            workers
# 0  Childish Gambino  Donald Glover & Ludwig Göransson, producers; D...
# 1   Kacey Musgraves  Ian Fitchuk, Kacey Musgraves & Daniel Tashian,...
# 2                    Donald Glover, Ludwig Göransson & Jeffery Lama...
